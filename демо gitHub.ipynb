# %% [markdown]
# <a href="https://colab.research.google.com/github/myrzenish1985-web/Shestakova_DA/blob/main/%D0%B4%D0%B5%D0%BC%D0%BE%20gitHub.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
x = np.pi

# %%
y = 1

# %%
x + y
# Out:
# 4.141592653589793

# %%
print (np.sin (x))
# Out:
# 1.2246467991473532e-16

# %%
x*y*2
# Out:
# 6.283185307179586
